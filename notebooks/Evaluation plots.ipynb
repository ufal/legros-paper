71.35,70.63,70.30,69.85,69.12,68.22,68.07,67.45,66.60,65.92,65.31,64.58,63.83,63.05,62.57,61.69,60.81,60.22,58.95,57.87,56.49,54.36,53.52,52.33,51.28,50.50,49.23,49.12,45.60]

ours_from_sp_prec = [76.90, 80.37,80.35,80.40,80.44,80.39,80.38,80.39,80.39,80.38,80.38,80.38,80.38,80.38,80.38,80.38,80.38,80.38,80.38,80.38,80.38,80.38,80.38,80.38,80.38,80.38]
ours_from_sp_sizes = [32000,29052,29037,29032,29029,29025,29025,29025,29024,29024,29023,29023,29023,29023,29023,29023,29023,29023,29023,29023,29023,29023,29023,29023,29023,29023,]

ours_improved_sp_sizes = [993, 1927, 3783, 7472, 14845, 29023, 56505, 85099, 116190, 132523, 136197, 138351, 139921, 142136]
ours_improved_sp_prec =  [62.60, 66.32, 70.38, 74.10, 77.24, 80.38, 83.62, 85.25, 85.79, 86.06, 86.23, 86.41, 86.41, 86.28]

bigram_counts_prec = [62.90,66.53,70.39,74.02,76.83,80.16,83.27,84.90,85.79,86.19,86.13,86.20,86.35,86.22]
bigram_neural_prec = [61.95,65.54,69.45,72.27,74.97,77.90,81.33,83.32,83.97]

morfessor_vocab = 248915
morfessor_prec = 92.08

ours_morfessor_vocab = [66972, 60264,54219,48787,43901,39504,35548,31989,28787,25906,23312,20978,18875,16987,15999,15287,13757,12380,11141,10025,9022,8119]
ours_morfessor_prec = [89.34, 88.66,88.17,87.78,87.31,86.80,86.42,85.78,85.19,84.87,84.38,83.72,82.81,82.36,81.90,81.67,81.08,80.41,79.71,79.12,78.71,78.22]

# %%
plt.plot(bpe_sizes, bpe_prec, label="BPE")
plt.plot(sp_sizes, sp_prec, label="SentencePiece")
plt.plot([morfessor_vocab], [morfessor_prec], label="Morfessor", marker="*", markersize=10, linewidth=0)
plt.plot([9672], [89.99], label="Ours, oracle w/ train data", marker="*", markersize=10, linewidth=0)

plt.plot(ours_most_freq_sizes, ours_most_freq_prec, label="Ours, most freq. substr., sum")

#plt.plot(ours_first_sizes, ours_first_prec, label="Ours buggy")
#plt.plot(ours_with_allowed_sizes, ours_with_allowed_prec, label="Ours, 5 samples")
#plt.plot(ours_nosample_sizes, ours_nosample_prec, label="Ours, best segment")
plt.plot(ours_vocab_decrease_sizes, ours_vocab_decrease_prec, label="Ours with decreasing")
#plt.plot(ours_from_sp_sizes, ours_from_sp_prec, label="Ours, init w/ SP")
plt.plot(ours_improved_sp_sizes, ours_improved_sp_prec, label="Ours, init w/ SP")
plt.plot(ours_improved_sp_sizes, bigram_counts_prec, label="Bigram counts from ours")
#lt.plot(ours_improved_sp_sizes[:9], bigram_neural_prec, label="Bigram neural model from ours", marker=".", markersize=10)


plt.plot(ours_morfessor_vocab[0], ours_morfessor_prec[0],
         label="Ours, init w/ Morfessor", marker=".", markersize=10, linewidth=0, color="C2")
plt.plot(ours_morfessor_vocab, ours_morfessor_prec,
         label="Ours, init w/ Morfessor", color="C2")
plt.arrow(
    x=morfessor_vocab, y=morfessor_prec,
    dx=ours_morfessor_vocab[0] - morfessor_vocab,
    dy=ours_morfessor_prec[0] - morfessor_prec,
    color='lightgray', width=0.1, linestyle="--")

for sp_vocab, sp_p, ours_vocab, ours_prec in zip(sp_sizes, sp_prec, ours_improved_sp_sizes, ours_improved_sp_prec):
    plt.arrow(
        x=sp_vocab, y=sp_p,
        dy=ours_prec-sp_p, dx=ours_vocab-sp_vocab,
        color='lightgray', width=0.1, linestyle="--")


#plt.plot(ours_maxmin_sizes[:len(ours_maxmin_prec)], ours_maxmin_prec, label="Ours, most freq. substr., max-min")

plt.xlabel("Subword vocabulary")
plt.xlim(0, 200000)
plt.ylim(60, 93)
plt.ylabel("Precision")
plt.legend(loc="lower right", fontsize=8)
